# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, Polygon
from shapely.affinity import translate
from glob2 import glob

# %% [markdown]
# ## Load data

# %%
#load geojson
park_forest_overpass=gpd.read_file('../data/geojson/london_park_forest.json', drive='GeoJSON')

# %%
#the geojson can be called using the code below 
#https://overpass-turbo.eu/
'''

/*
This is an example Overpass query.
Try it out by pressing the Run button above!
You can find more examples with the Load tool.
*/
(
nwr[leisure=park](51.251601468176545,-0.720977783203125,51.72702815704774,0.545196533203125);
nwr[landuse=forest](51.251601468176545,-0.720977783203125,51.72702815704774,0.545196533203125);
);
out geom;

'''
''''''
# Out:
# ''

# %%
#keep only polygons

#exclude Point
park_forest_overpass=park_forest_overpass[park_forest_overpass['geometry'].geom_type.ne('Point')]
#exclude LineString
park_forest_overpass=park_forest_overpass[park_forest_overpass['geometry'].geom_type.ne('LineString')]

# %%
park_forest_overpass.head()
# Out:
#                id             @id landuse                  name          type  \
# 0  relation/12098  relation/12098  forest  Newmeadow Plantation  multipolygon
# 1  relation/18721  relation/18721    None               Horndon  multipolygon
# 2  relation/28717  relation/28717  forest                  None  multipolygon
# 3  relation/35150  relation/35150   grass          Raphael Park  multipolygon
# 4  relation/70348  relation/70348    None    Tanner Street Park  multipolygon
#
#   leisure  wikidata        wikipedia source source:name  ... multipolygon  \
# 0    None      None             None   None        None  ...         None
# 1    park      None             None   None        None  ...         None
# 2    None      None             None   None        None  ...         None
# 3    park  Q7294001  en:Raphael Park   None        None  ...         None
# 4    park      None             None   None        None  ...         None
#
#   parking note:history construction not:designation disused:leisure  \
# 0    None         None         None            None            None
# 1    None         None         None            None            None
# 2    None         None         None            None            None
# 3    None         None         None            None            None
# 4    None         None         None            None            None
#
#   garden:type bench species:en  \
# 0        None  None       None
# 1        None  None       None
# 2        None  None       None
# 3        None  None       None
# 4        None  None       None
#
#                                             geometry
# 0  POLYGON ((-0.60303 51.45948, -0.60368 51.45910...
# 1  POLYGON ((0.39837 51.52229, 0.39910 51.52251, ...
# 2  POLYGON ((-0.19293 51.59804, -0.19296 51.59791...
# 3  POLYGON ((0.18899 51.59232, 0.18928 51.59262, ...
# 4  POLYGON ((-0.07945 51.49964, -0.07934 51.50012...
#
# [5 rows x 180 columns]

# %%
park_forest_overpass.shape
# Out:
# (6740, 180)

# %%
park_forest_overpass.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ## Exclude the overlapping geometries

# %%
geom = park_forest_overpass.geometry.unary_union

# %%
park_forest_unique = gpd.GeoDataFrame(geometry=[geom],crs="epsg:4326")

# %%
park_forest_unique.head()
# Out:
#                                             geometry
# 0  MULTIPOLYGON (((0.06496 51.43832, 0.06488 51.4...

# %%
park_forest_unique.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
park_forest_unique = park_forest_unique.explode().reset_index(drop=True)

# %%
park_forest_unique.head()
# Out:
#                                             geometry
# 0  POLYGON ((0.06496 51.43832, 0.06488 51.43848, ...
# 1  POLYGON ((-0.66613 51.42098, -0.66546 51.42124...
# 2  POLYGON ((-0.03131 51.43360, -0.03027 51.43355...
# 3  POLYGON ((-0.24209 51.45606, -0.24205 51.45651...
# 4  POLYGON ((-0.51873 51.48176, -0.51901 51.48187...

# %%
park_forest_unique.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
park_forest_unique.shape
# Out:
# (5966, 1)

# %% [markdown]
# ## Load observations

# %%
data_folder = '../data/data_muki/data'
london_df = pd.concat([pd.read_csv(f).assign(challenge=f.replace('.csv','')) for f in glob(data_folder+'/CNC London*.csv')])

# %%
london_df.shape
# Out:
# (13730, 35)

# %%
london_df.head()
# Out:
#          id                         observed_on_string observed_on  \
# 0  11479007                  2018-04-27 7:52:34 am BST  2018-04-27
# 1  11480212                  2018-04-27 8:39:41 am BST  2018-04-27
# 2  11480902  Fri Apr 27 2018 08:34:31 GMT+0100 (GMT+1)  2018-04-27
# 3  11481097  Fri Apr 27 2018 09:54:35 GMT+0100 (GMT+1)  2018-04-27
# 4  11482247                  2018-04-27 8:42:21 am BST  2018-04-27
#
#           time_observed_at  time_zone  user_id       user_login  \
# 0  2018-04-27 07:52:34 UTC        UTC   159021             muki
# 1  2018-04-27 07:39:41 UTC     London   664459  lucyrobinsonnhm
# 2  2018-04-27 06:34:31 UTC  Amsterdam   908315           tess26
# 3  2018-04-27 07:54:35 UTC  Amsterdam   796473      bryonycross
# 4  2018-04-27 07:42:21 UTC     London   664459  lucyrobinsonnhm
#
#                 created_at               updated_at quality_grade  ...  \
# 0  2018-04-27 07:06:17 UTC  2018-04-27 09:26:56 UTC      research  ...
# 1  2018-04-27 08:02:52 UTC  2019-01-29 21:16:34 UTC      research  ...
# 2  2018-04-27 08:42:01 UTC  2018-04-27 11:01:49 UTC        casual  ...
# 3  2018-04-27 08:54:45 UTC  2018-04-27 20:23:41 UTC      research  ...
# 4  2018-04-27 10:09:55 UTC  2018-04-27 15:37:31 UTC      research  ...
#
#   taxon_geoprivacy coordinates_obscured positioning_method positioning_device  \
# 0              NaN                False                gps                gps
# 1             open                False                gps                gps
# 2              NaN                False                NaN                NaN
# 3              NaN                False                NaN                NaN
# 4              NaN                False                gps                gps
#
#              species_guess            scientific_name       common_name  \
# 0         lesser celandine              Ficaria verna  lesser celandine
# 1  Pigeon biset domestique    Columba livia domestica      Feral Pigeon
# 2                      NaN    Hyacinthoides hispanica  Spanish Bluebell
# 3            Green Alkanet  Pentaglottis sempervirens     Green Alkanet
# 4             London Plane       Platanus × hispanica      London Plane
#
#    iconic_taxon_name  taxon_id                               challenge
# 0            Plantae  204321.0  ../data/data_muki/data\CNC London 2018
# 1               Aves  122767.0  ../data/data_muki/data\CNC London 2018
# 2            Plantae   57635.0  ../data/data_muki/data\CNC London 2018
# 3            Plantae  166466.0  ../data/data_muki/data\CNC London 2018
# 4            Plantae  552449.0  ../data/data_muki/data\CNC London 2018
#
# [5 rows x 35 columns]

# %%
london_df['latitude'], london_df['longitude']
# Out:
# (0       51.550636
#  1       51.495277
#  2       51.472981
#  3       51.508076
#  4       51.496113
#            ...
#  5756    51.374607
#  5757    51.540178
#  5758    51.564122
#  5759    51.503484
#  5760    51.411946
#  Name: latitude, Length: 13730, dtype: float64, 0      -0.228487
#  1      -0.173611
#  2      -0.169102
#  3      -0.161516
#  4      -0.173889
#            ...
#  5756   -0.171098
#  5757   -0.329124
#  5758   -0.334986
#  5759   -0.346972
#  5760   -0.288115
#  Name: longitude, Length: 13730, dtype: float64)

# %%
#create the points inverting the coordinates
geometry_invert = [Point(xy) for xy in zip(london_df.longitude, london_df.latitude)]

# %%
#crete a geodataframe with the observations
observations_gdf = gpd.GeoDataFrame(london_df, crs="epsg:4326", geometry=geometry_invert)

# %%
observations_gdf.shape
# Out:
# (13730, 36)

# %%
observations_gdf.head()
# Out:
#          id                         observed_on_string observed_on  \
# 0  11479007                  2018-04-27 7:52:34 am BST  2018-04-27
# 1  11480212                  2018-04-27 8:39:41 am BST  2018-04-27
# 2  11480902  Fri Apr 27 2018 08:34:31 GMT+0100 (GMT+1)  2018-04-27
# 3  11481097  Fri Apr 27 2018 09:54:35 GMT+0100 (GMT+1)  2018-04-27
# 4  11482247                  2018-04-27 8:42:21 am BST  2018-04-27
#
#           time_observed_at  time_zone  user_id       user_login  \
# 0  2018-04-27 07:52:34 UTC        UTC   159021             muki
# 1  2018-04-27 07:39:41 UTC     London   664459  lucyrobinsonnhm
# 2  2018-04-27 06:34:31 UTC  Amsterdam   908315           tess26
# 3  2018-04-27 07:54:35 UTC  Amsterdam   796473      bryonycross
# 4  2018-04-27 07:42:21 UTC     London   664459  lucyrobinsonnhm
#
#                 created_at               updated_at quality_grade  ...  \
# 0  2018-04-27 07:06:17 UTC  2018-04-27 09:26:56 UTC      research  ...
# 1  2018-04-27 08:02:52 UTC  2019-01-29 21:16:34 UTC      research  ...
# 2  2018-04-27 08:42:01 UTC  2018-04-27 11:01:49 UTC        casual  ...
# 3  2018-04-27 08:54:45 UTC  2018-04-27 20:23:41 UTC      research  ...
# 4  2018-04-27 10:09:55 UTC  2018-04-27 15:37:31 UTC      research  ...
#
#   coordinates_obscured positioning_method positioning_device  \
# 0                False                gps                gps
# 1                False                gps                gps
# 2                False                NaN                NaN
# 3                False                NaN                NaN
# 4                False                gps                gps
#
#              species_guess            scientific_name       common_name  \
# 0         lesser celandine              Ficaria verna  lesser celandine
# 1  Pigeon biset domestique    Columba livia domestica      Feral Pigeon
# 2                      NaN    Hyacinthoides hispanica  Spanish Bluebell
# 3            Green Alkanet  Pentaglottis sempervirens     Green Alkanet
# 4             London Plane       Platanus × hispanica      London Plane
#
#    iconic_taxon_name  taxon_id                               challenge  \
# 0            Plantae  204321.0  ../data/data_muki/data\CNC London 2018
# 1               Aves  122767.0  ../data/data_muki/data\CNC London 2018
# 2            Plantae   57635.0  ../data/data_muki/data\CNC London 2018
# 3            Plantae  166466.0  ../data/data_muki/data\CNC London 2018
# 4            Plantae  552449.0  ../data/data_muki/data\CNC London 2018
#
#                     geometry
# 0  POINT (-0.22849 51.55064)
# 1  POINT (-0.17361 51.49528)
# 2  POINT (-0.16910 51.47298)
# 3  POINT (-0.16152 51.50808)
# 4  POINT (-0.17389 51.49611)
#
# [5 rows x 36 columns]

# %% [markdown]
# ## Spatial join

# %%
# spatial join observations and observations.
points_polys = gpd.sjoin(observations_gdf, park_forest_unique, how='inner')

# %%
points_polys.head()
# Out:
#           id                         observed_on_string observed_on  \
# 3   11481097  Fri Apr 27 2018 09:54:35 GMT+0100 (GMT+1)  2018-04-27
# 5   11482706  Fri Apr 27 2018 11:40:06 GMT+0100 (GMT+1)  2018-04-27
# 6   11483083  Fri Apr 27 2018 12:01:15 GMT+0100 (GMT+1)  2018-04-27
# 10  11484564  Fri Apr 27 2018 12:58:17 GMT+0100 (GMT+1)  2018-04-27
# 11  11484587  Fri Apr 27 2018 12:58:55 GMT+0100 (GMT+1)  2018-04-27
#
#            time_observed_at  time_zone  user_id   user_login  \
# 3   2018-04-27 07:54:35 UTC  Amsterdam   796473  bryonycross
# 5   2018-04-27 09:40:06 UTC  Amsterdam   796473  bryonycross
# 6   2018-04-27 10:01:15 UTC  Amsterdam   796473  bryonycross
# 10  2018-04-27 10:58:17 UTC  Amsterdam   796473  bryonycross
# 11  2018-04-27 10:58:55 UTC  Amsterdam   796473  bryonycross
#
#                  created_at               updated_at quality_grade  ...  \
# 3   2018-04-27 08:54:45 UTC  2018-04-27 20:23:41 UTC      research  ...
# 5   2018-04-27 10:40:31 UTC  2018-04-27 17:18:08 UTC        casual  ...
# 6   2018-04-27 11:01:48 UTC  2018-04-27 17:18:09 UTC      needs_id  ...
# 10  2018-04-27 11:58:34 UTC  2018-04-27 17:18:10 UTC      research  ...
# 11  2018-04-27 11:59:13 UTC  2018-04-27 17:18:11 UTC      needs_id  ...
#
#    positioning_method positioning_device  species_guess  \
# 3                 NaN                NaN  Green Alkanet
# 5                 NaN                NaN            NaN
# 6                 NaN                NaN            NaN
# 10                NaN                NaN   Garden Snail
# 11                NaN                NaN            NaN
#
#               scientific_name            common_name iconic_taxon_name  \
# 3   Pentaglottis sempervirens          Green Alkanet           Plantae
# 5            Quercus stellata               post oak           Plantae
# 6                 Oligochaeta  Earthworms and allies          Animalia
# 10             Cornu aspersum           Garden Snail          Mollusca
# 11                Arion rufus        Chocolate Arion          Mollusca
#
#     taxon_id                               challenge  \
# 3   166466.0  ../data/data_muki/data\CNC London 2018
# 5   119269.0  ../data/data_muki/data\CNC London 2018
# 6   333586.0  ../data/data_muki/data\CNC London 2018
# 10  480298.0  ../data/data_muki/data\CNC London 2018
# 11   84755.0  ../data/data_muki/data\CNC London 2018
#
#                      geometry  index_right
# 3   POINT (-0.16152 51.50808)         2427
# 5   POINT (-0.16758 51.51051)         2427
# 6   POINT (-0.16793 51.51077)         2427
# 10  POINT (-0.16176 51.50792)         2427
# 11  POINT (-0.16168 51.50783)         2427
#
# [5 rows x 37 columns]

# %%
points_polys.shape
# Out:
# (5847, 37)

# %%
points_polys.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ## Set flag for greenspaces

# %%
ids_with_greenspace = points_polys.id.to_list()

# %%
new_london = london_df.set_index('id')
new_london.head()
# Out:
#                                  observed_on_string observed_on  \
# id
# 11479007                  2018-04-27 7:52:34 am BST  2018-04-27
# 11480212                  2018-04-27 8:39:41 am BST  2018-04-27
# 11480902  Fri Apr 27 2018 08:34:31 GMT+0100 (GMT+1)  2018-04-27
# 11481097  Fri Apr 27 2018 09:54:35 GMT+0100 (GMT+1)  2018-04-27
# 11482247                  2018-04-27 8:42:21 am BST  2018-04-27
#
#                  time_observed_at  time_zone  user_id       user_login  \
# id
# 11479007  2018-04-27 07:52:34 UTC        UTC   159021             muki
# 11480212  2018-04-27 07:39:41 UTC     London   664459  lucyrobinsonnhm
# 11480902  2018-04-27 06:34:31 UTC  Amsterdam   908315           tess26
# 11481097  2018-04-27 07:54:35 UTC  Amsterdam   796473      bryonycross
# 11482247  2018-04-27 07:42:21 UTC     London   664459  lucyrobinsonnhm
#
#                        created_at               updated_at quality_grade  \
# id
# 11479007  2018-04-27 07:06:17 UTC  2018-04-27 09:26:56 UTC      research
# 11480212  2018-04-27 08:02:52 UTC  2019-01-29 21:16:34 UTC      research
# 11480902  2018-04-27 08:42:01 UTC  2018-04-27 11:01:49 UTC        casual
# 11481097  2018-04-27 08:54:45 UTC  2018-04-27 20:23:41 UTC      research
# 11482247  2018-04-27 10:09:55 UTC  2018-04-27 15:37:31 UTC      research
#
#            license  ... coordinates_obscured positioning_method  \
# id                  ...
# 11479007     CC-BY  ...                False                gps
# 11480212       CC0  ...                False                gps
# 11480902       NaN  ...                False                NaN
# 11481097  CC-BY-NC  ...                False                NaN
# 11482247       CC0  ...                False                gps
#
#          positioning_device            species_guess  \
# id
# 11479007                gps         lesser celandine
# 11480212                gps  Pigeon biset domestique
# 11480902                NaN                      NaN
# 11481097                NaN            Green Alkanet
# 11482247                gps             London Plane
#
#                     scientific_name       common_name  iconic_taxon_name  \
# id
# 11479007              Ficaria verna  lesser celandine            Plantae
# 11480212    Columba livia domestica      Feral Pigeon               Aves
# 11480902    Hyacinthoides hispanica  Spanish Bluebell            Plantae
# 11481097  Pentaglottis sempervirens     Green Alkanet            Plantae
# 11482247       Platanus × hispanica      London Plane            Plantae
#
#           taxon_id                               challenge  \
# id
# 11479007  204321.0  ../data/data_muki/data\CNC London 2018
# 11480212  122767.0  ../data/data_muki/data\CNC London 2018
# 11480902   57635.0  ../data/data_muki/data\CNC London 2018
# 11481097  166466.0  ../data/data_muki/data\CNC London 2018
# 11482247  552449.0  ../data/data_muki/data\CNC London 2018
#
#                            geometry
# id
# 11479007  POINT (-0.22849 51.55064)
# 11480212  POINT (-0.17361 51.49528)
# 11480902  POINT (-0.16910 51.47298)
# 11481097  POINT (-0.16152 51.50808)
# 11482247  POINT (-0.17389 51.49611)
#
# [5 rows x 35 columns]

# %%
new_london['greenspace_flag'] = '0'
new_london.loc[ids_with_greenspace,'greenspace_flag'] = '1'

# %%
new_london.greenspace_flag.value_counts()
# Out:
# 0    7883
# 1    5847
# Name: greenspace_flag, dtype: int64

# %%
new_london.head()
# Out:
#                                  observed_on_string observed_on  \
# id
# 11479007                  2018-04-27 7:52:34 am BST  2018-04-27
# 11480212                  2018-04-27 8:39:41 am BST  2018-04-27
# 11480902  Fri Apr 27 2018 08:34:31 GMT+0100 (GMT+1)  2018-04-27
# 11481097  Fri Apr 27 2018 09:54:35 GMT+0100 (GMT+1)  2018-04-27
# 11482247                  2018-04-27 8:42:21 am BST  2018-04-27
#
#                  time_observed_at  time_zone  user_id       user_login  \
# id
# 11479007  2018-04-27 07:52:34 UTC        UTC   159021             muki
# 11480212  2018-04-27 07:39:41 UTC     London   664459  lucyrobinsonnhm
# 11480902  2018-04-27 06:34:31 UTC  Amsterdam   908315           tess26
# 11481097  2018-04-27 07:54:35 UTC  Amsterdam   796473      bryonycross
# 11482247  2018-04-27 07:42:21 UTC     London   664459  lucyrobinsonnhm
#
#                        created_at               updated_at quality_grade  \
# id
# 11479007  2018-04-27 07:06:17 UTC  2018-04-27 09:26:56 UTC      research
# 11480212  2018-04-27 08:02:52 UTC  2019-01-29 21:16:34 UTC      research
# 11480902  2018-04-27 08:42:01 UTC  2018-04-27 11:01:49 UTC        casual
# 11481097  2018-04-27 08:54:45 UTC  2018-04-27 20:23:41 UTC      research
# 11482247  2018-04-27 10:09:55 UTC  2018-04-27 15:37:31 UTC      research
#
#            license  ... positioning_method positioning_device  \
# id                  ...
# 11479007     CC-BY  ...                gps                gps
# 11480212       CC0  ...                gps                gps
# 11480902       NaN  ...                NaN                NaN
# 11481097  CC-BY-NC  ...                NaN                NaN
# 11482247       CC0  ...                gps                gps
#
#                     species_guess            scientific_name  \
# id
# 11479007         lesser celandine              Ficaria verna
# 11480212  Pigeon biset domestique    Columba livia domestica
# 11480902                      NaN    Hyacinthoides hispanica
# 11481097            Green Alkanet  Pentaglottis sempervirens
# 11482247             London Plane       Platanus × hispanica
#
#                common_name  iconic_taxon_name  taxon_id  \
# id
# 11479007  lesser celandine            Plantae  204321.0
# 11480212      Feral Pigeon               Aves  122767.0
# 11480902  Spanish Bluebell            Plantae   57635.0
# 11481097     Green Alkanet            Plantae  166466.0
# 11482247      London Plane            Plantae  552449.0
#
#                                        challenge                   geometry  \
# id
# 11479007  ../data/data_muki/data\CNC London 2018  POINT (-0.22849 51.55064)
# 11480212  ../data/data_muki/data\CNC London 2018  POINT (-0.17361 51.49528)
# 11480902  ../data/data_muki/data\CNC London 2018  POINT (-0.16910 51.47298)
# 11481097  ../data/data_muki/data\CNC London 2018  POINT (-0.16152 51.50808)
# 11482247  ../data/data_muki/data\CNC London 2018  POINT (-0.17389 51.49611)
#
#          greenspace_flag
# id
# 11479007               0
# 11480212               0
# 11480902               0
# 11481097               1
# 11482247               0
#
# [5 rows x 36 columns]

# %%
#export as csv
new_london.to_csv('../data/outputs/london_data_with_greenspace_flag.csv')

# %%
#compare with Florence's csv export
new_london_v0=pd.read_csv('../data/outputs/london_data_with_greenspace_flag_v1.csv')

# %%
new_london_v0.shape, new_london.shape
# Out:
# ((13730, 38), (13730, 36))

# %%
#no columns E and N in the new df
new_london_v0.columns, new_london.columns
# Out:
# (Index(['id', 'observed_on_string', 'observed_on', 'time_observed_at',
#         'time_zone', 'user_id', 'user_login', 'created_at', 'updated_at',
#         'quality_grade', 'license', 'url', 'image_url', 'sound_url', 'tag_list',
#         'description', 'num_identification_agreements',
#         'num_identification_disagreements', 'captive_cultivated',
#         'oauth_application_id', 'place_guess', 'latitude', 'longitude',
#         'positional_accuracy', 'geoprivacy', 'taxon_geoprivacy',
#         'coordinates_obscured', 'positioning_method', 'positioning_device',
#         'species_guess', 'scientific_name', 'common_name', 'iconic_taxon_name',
#         'taxon_id', 'challenge', 'E', 'N', 'greenspace_flag'],
#        dtype='object'),
#  Index(['observed_on_string', 'observed_on', 'time_observed_at', 'time_zone',
#         'user_id', 'user_login', 'created_at', 'updated_at', 'quality_grade',
#         'license', 'url', 'image_url', 'sound_url', 'tag_list', 'description',
#         'num_identification_agreements', 'num_identification_disagreements',
#         'captive_cultivated', 'oauth_application_id', 'place_guess', 'latitude',
#         'longitude', 'positional_accuracy', 'geoprivacy', 'taxon_geoprivacy',
#         'coordinates_obscured', 'positioning_method', 'positioning_device',
#         'species_guess', 'scientific_name', 'common_name', 'iconic_taxon_name',
#         'taxon_id', 'challenge', 'geometry', 'greenspace_flag'],
#        dtype='object'))

# %%
new_london_v0.greenspace_flag.value_counts()
# Out:
# 0    8235
# 1    5495
# Name: greenspace_flag, dtype: int64

# %%
new_london.greenspace_flag.value_counts()
# Out:
# 0    7883
# 1    5847
# Name: greenspace_flag, dtype: int64

# %%
5847-5495
# Out:
# 352

# %% [markdown]
# ### 352 more observations (n=13730) with greenspace_flag = 1
