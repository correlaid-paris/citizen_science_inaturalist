# %% [markdown]
# # Get the greenspaces from Los Angeles and set the flags

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, Polygon
from glob2 import glob
import osmnx as ox

# %%
#get California as gdf to check anomalies later. Points outside California will be excluded
ca=ox.geocode_to_gdf('California')

# %%
ca
# Out:
#                                             geometry  bbox_north  bbox_south  \
# 0  MULTIPOLYGON (((-124.48200 40.44032, -124.4813...   42.009499   32.529524
#
#     bbox_east   bbox_west   place_id  osm_type  osm_id        lat         lon  \
# 0 -114.130782 -124.482003  259044285  relation  165475  36.701463 -118.755997
#
#                 display_name     class            type  importance
# 0  California, United States  boundary  administrative    0.922136

# %% [markdown]
# ## Load observations (API)

# %%
data_folder = '../data/observations_final'
la_df = pd.concat([pd.read_csv(f).assign(challenge=f.replace('.csv','')) for f in glob(data_folder+'/CNC_Los_Angeles_*.csv')])

# %%
la_df.shape
# Out:
# (91694, 39)

# %%
#check for incorrect points (lat)
la_df['latitude'].min(), la_df['latitude'].max()
# Out:
# (32.792719780300004, 76.3489192018)

# %%
#check for incorrect points (lon). Clearly something wrong!
la_df['longitude'].min(), la_df['longitude'].max()
# Out:
# (-118.9965502909, 130.01725921940002)

# %% [markdown]
# ## Get only the points inside CA

# %%
la_df=la_df[la_df['latitude'].le(ca['bbox_north'].iloc[0]) \
                  & la_df['latitude'].ge(ca['bbox_south'].iloc[0]) \
                  & la_df['longitude'].le(ca['bbox_east'].iloc[0]) \
                  & la_df['longitude'].ge(ca['bbox_west'].iloc[0])]

# %%
la_df.shape
# Out:
# (91693, 39)

# %%
la_df.head()
# Out:
#         id                       observed_on_string  \
# 0  5591391  Fri Apr 14 2017 09:34:12 GMT-0700 (PDT)
# 1  5591694  Sat Apr 15 2017 10:18:50 GMT-0700 (PDT)
# 2  5684540  Fri Apr 14 2017 00:03:16 GMT-0700 (PDT)
# 3  5684550  Fri Apr 14 2017 00:04:42 GMT-0700 (PDT)
# 4  5684551  Fri Apr 14 2017 00:04:06 GMT-0700 (PDT)
#
#             time_observed_at    created_time_zone                 created_at  \
# 0  2017-04-14T09:34:12-07:00  America/Los_Angeles  2017-04-06T09:34:29-07:00
# 1  2017-04-15T10:18:50-07:00  America/Los_Angeles  2017-04-06T10:19:03-07:00
# 2  2017-04-14T00:03:16-07:00  America/Los_Angeles  2017-04-14T00:04:16-07:00
# 3  2017-04-14T00:04:42-07:00  America/Los_Angeles  2017-04-14T00:05:31-07:00
# 4  2017-04-14T00:04:06-07:00  America/Los_Angeles  2017-04-14T00:05:32-07:00
#
#                   updated_at description  user_id user_login quality_grade  \
# 0  2018-01-13T14:28:01-08:00         NaN   436798  laurachun      research
# 1  2018-01-13T14:28:03-08:00         NaN   436798  laurachun      research
# 2  2018-01-13T14:31:44-08:00         NaN     6743   lhiggins      needs_id
# 3  2018-01-13T14:31:44-08:00         NaN     6743   lhiggins      needs_id
# 4  2017-04-14T05:30:19-07:00         NaN    15419  mordenana      needs_id
#
#    ... iconic_taxon_name  taxon_rank  taxon_parent_id  taxon_native  \
# 0  ...           Plantae     species            52855          True
# 1  ...           Plantae     species            53145          True
# 2  ...           Insecta      family            52380         False
# 3  ...          Mollusca       genus           933174         False
# 4  ...         Arachnida       order            47119         False
#
#    taxon_endemic  taxon_threatened  taxon_search_rank taxon_observations  \
# 0          False             False              11983              11983
# 1          False             False               6476               6476
# 2          False             False              55396              55396
# 3          False             False               8938               8938
# 4          False             False            1420015            1420015
#
#                                      identifications  \
# 0  [{'user_id': 73705, 'category': 'supporting', ...
# 1  [{'user_id': 73705, 'category': 'supporting', ...
# 2  [{'user_id': 275891, 'category': 'supporting',...
# 3  [{'user_id': 81261, 'category': 'improving', '...
# 4  [{'user_id': 15419, 'category': None, 'disagre...
#
#                                          challenge
# 0  ../data/observations_final\CNC_Los_Angeles_2017
# 1  ../data/observations_final\CNC_Los_Angeles_2017
# 2  ../data/observations_final\CNC_Los_Angeles_2017
# 3  ../data/observations_final\CNC_Los_Angeles_2017
# 4  ../data/observations_final\CNC_Los_Angeles_2017
#
# [5 rows x 39 columns]

# %% [markdown]
# ## Get the greenspaces using OSMnx and the points we defined before

# %%
green=ox.geometries.geometries_from_bbox(la_df['latitude'].max(),
                                         la_df['latitude'].min(),
                                         la_df['longitude'].max(),
                                         la_df['longitude'].min(),
                                         {'leisure':'park', 'landuse':'forest'})

# %%
green.shape
# Out:
# (4473, 144)

# %%
green.head(5)
# Out:
#         unique_id      osmid element_type ele gnis:county_id gnis:created  \
# 0  node/358786394  358786394         node  24            059   01/19/1981
# 1  node/358822072  358822072         node   3            059   12/02/1996
# 2  node/358822079  358822079         node   5            059   12/02/1996
# 3  node/358822080  358822080         node  -3            059   12/02/1996
# 4  node/358822082  358822082         node  -2            059   12/02/1996
#
#   gnis:feature_id gnis:state_id leisure                             name  ...  \
# 0          243909            06    park                 Irvine Bowl Park  ...
# 1         1702600            06    park            Capistrano Beach Park  ...
# 2         1702604            06    park    Dana Point Marine Life Refuge  ...
# 3         1702605            06    park        Doheny Marine Life Refuge  ...
# 4         1702606            06    park  Irvine Coast Marine Life Refuge  ...
#
#   longitude ownership protect_class taxon taxon:en studio conservation  \
# 0       NaN       NaN           NaN   NaN      NaN    NaN          NaN
# 1       NaN       NaN           NaN   NaN      NaN    NaN          NaN
# 2       NaN       NaN           NaN   NaN      NaN    NaN          NaN
# 3       NaN       NaN           NaN   NaN      NaN    NaN          NaN
# 4       NaN       NaN           NaN   NaN      NaN    NaN          NaN
#
#   protected_area  FID protection_title
# 0            NaN  NaN              NaN
# 1            NaN  NaN              NaN
# 2            NaN  NaN              NaN
# 3            NaN  NaN              NaN
# 4            NaN  NaN              NaN
#
# [5 rows x 144 columns]

# %%
#keep only polygons

#exclude Point
green=green[green['geometry'].geom_type.ne('Point')]
#exclude LineString
green=green[green['geometry'].geom_type.ne('LineString')]

# %%
green.shape
# Out:
# (4228, 144)

# %% [markdown]
# ## Exclude the overlapping geometries

# %%
geom = green.geometry.unary_union

# %%
green_unique = gpd.GeoDataFrame(geometry=[geom],crs='epsg:4326')

# %%
green_unique.head()
# Out:
#                                             geometry
# 0  MULTIPOLYGON (((-118.33014 33.33963, -118.3301...

# %%
green_unique.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
green_unique = green_unique.explode().reset_index(drop=True)

# %%
green_unique.head()
# Out:
#                                             geometry
# 0  POLYGON ((-118.33014 33.33963, -118.33011 33.3...
# 1  POLYGON ((-118.32523 33.34060, -118.32513 33.3...
# 2  POLYGON ((-118.32373 33.34246, -118.32370 33.3...
# 3  POLYGON ((-118.32504 33.34339, -118.32508 33.3...
# 4  POLYGON ((-117.61153 33.41189, -117.61184 33.4...

# %%
green_unique.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
green_unique.shape
# Out:
# (4089, 1)

# %% [markdown]
# ## Create gdf using the observations

# %%
la_df['longitude'].isna().sum(), la_df['latitude'].isna().sum()
# Out:
# (0, 0)

# %%
#create the points inverting the coordinates
geometry_invert = [Point(xy) for xy in zip(la_df.longitude, la_df.latitude)]

# %%
#crete a geodataframe with the observations
observations_gdf = gpd.GeoDataFrame(la_df, crs='epsg:4326', geometry=geometry_invert)

# %%
observations_gdf.shape
# Out:
# (91693, 40)

# %%
observations_gdf.head()
# Out:
#         id                       observed_on_string  \
# 0  5591391  Fri Apr 14 2017 09:34:12 GMT-0700 (PDT)
# 1  5591694  Sat Apr 15 2017 10:18:50 GMT-0700 (PDT)
# 2  5684540  Fri Apr 14 2017 00:03:16 GMT-0700 (PDT)
# 3  5684550  Fri Apr 14 2017 00:04:42 GMT-0700 (PDT)
# 4  5684551  Fri Apr 14 2017 00:04:06 GMT-0700 (PDT)
#
#             time_observed_at    created_time_zone                 created_at  \
# 0  2017-04-14T09:34:12-07:00  America/Los_Angeles  2017-04-06T09:34:29-07:00
# 1  2017-04-15T10:18:50-07:00  America/Los_Angeles  2017-04-06T10:19:03-07:00
# 2  2017-04-14T00:03:16-07:00  America/Los_Angeles  2017-04-14T00:04:16-07:00
# 3  2017-04-14T00:04:42-07:00  America/Los_Angeles  2017-04-14T00:05:31-07:00
# 4  2017-04-14T00:04:06-07:00  America/Los_Angeles  2017-04-14T00:05:32-07:00
#
#                   updated_at description  user_id user_login quality_grade  \
# 0  2018-01-13T14:28:01-08:00         NaN   436798  laurachun      research
# 1  2018-01-13T14:28:03-08:00         NaN   436798  laurachun      research
# 2  2018-01-13T14:31:44-08:00         NaN     6743   lhiggins      needs_id
# 3  2018-01-13T14:31:44-08:00         NaN     6743   lhiggins      needs_id
# 4  2017-04-14T05:30:19-07:00         NaN    15419  mordenana      needs_id
#
#    ... taxon_rank  taxon_parent_id  taxon_native  taxon_endemic  \
# 0  ...    species            52855          True          False
# 1  ...    species            53145          True          False
# 2  ...     family            52380         False          False
# 3  ...      genus           933174         False          False
# 4  ...      order            47119         False          False
#
#    taxon_threatened  taxon_search_rank  taxon_observations  \
# 0             False              11983               11983
# 1             False               6476                6476
# 2             False              55396               55396
# 3             False               8938                8938
# 4             False            1420015             1420015
#
#                                      identifications  \
# 0  [{'user_id': 73705, 'category': 'supporting', ...
# 1  [{'user_id': 73705, 'category': 'supporting', ...
# 2  [{'user_id': 275891, 'category': 'supporting',...
# 3  [{'user_id': 81261, 'category': 'improving', '...
# 4  [{'user_id': 15419, 'category': None, 'disagre...
#
#                                          challenge  \
# 0  ../data/observations_final\CNC_Los_Angeles_2017
# 1  ../data/observations_final\CNC_Los_Angeles_2017
# 2  ../data/observations_final\CNC_Los_Angeles_2017
# 3  ../data/observations_final\CNC_Los_Angeles_2017
# 4  ../data/observations_final\CNC_Los_Angeles_2017
#
#                       geometry
# 0  POINT (-118.20138 34.09752)
# 1  POINT (-118.20141 34.09936)
# 2  POINT (-118.31088 34.07109)
# 3  POINT (-118.31077 34.07111)
# 4  POINT (-117.99642 34.14409)
#
# [5 rows x 40 columns]

# %% [markdown]
# ## Spatial join

# %%
# spatial join observations and observations.
points_polys = gpd.sjoin(observations_gdf, green_unique, how='inner')

# %%
points_polys.head()
# Out:
#            id                       observed_on_string  \
# 0     5591391  Fri Apr 14 2017 09:34:12 GMT-0700 (PDT)
# 1     5591694  Sat Apr 15 2017 10:18:50 GMT-0700 (PDT)
# 3697  5733872  Sat Apr 15 2017 14:09:39 GMT-0700 (PDT)
# 3702  5733938  Sat Apr 15 2017 07:54:21 GMT-0700 (PDT)
# 3707  5734002  Sat Apr 15 2017 10:05:04 GMT-0700 (PDT)
#
#                time_observed_at    created_time_zone  \
# 0     2017-04-14T09:34:12-07:00  America/Los_Angeles
# 1     2017-04-15T10:18:50-07:00  America/Los_Angeles
# 3697  2017-04-15T14:09:39-07:00  America/Los_Angeles
# 3702  2017-04-15T07:54:21-07:00  America/Los_Angeles
# 3707  2017-04-15T10:05:04-07:00  America/Los_Angeles
#
#                      created_at                 updated_at  \
# 0     2017-04-06T09:34:29-07:00  2018-01-13T14:28:01-08:00
# 1     2017-04-06T10:19:03-07:00  2018-01-13T14:28:03-08:00
# 3697  2017-04-15T14:13:45-07:00  2018-01-13T14:44:03-08:00
# 3702  2017-04-15T14:14:33-07:00  2018-01-13T14:44:04-08:00
# 3707  2017-04-15T14:16:11-07:00  2018-01-13T14:44:05-08:00
#
#                                             description  user_id user_login  \
# 0                                                   NaN   436798  laurachun
# 1                                                   NaN   436798  laurachun
# 3697  Observation and photo by Martha Singer, sent t...   262752  alexbroad
# 3702  Observation and photo by Martha Singer, sent t...   262752  alexbroad
# 3707  Observation and photo by Martha Singer, sent t...   262752  alexbroad
#
#      quality_grade  ... taxon_parent_id  taxon_native  taxon_endemic  \
# 0         research  ...           52855          True          False
# 1         research  ...           53145          True          False
# 3697      research  ...           49921          True          False
# 3702      needs_id  ...            4950          True          False
# 3707      research  ...           14889          True          False
#
#       taxon_threatened  taxon_search_rank  taxon_observations  \
# 0                False              11983               11983
# 1                False               6476                6476
# 3697             False              17659               17659
# 3702             False             105228              105228
# 3707             False               3866                3866
#
#                                         identifications  \
# 0     [{'user_id': 73705, 'category': 'supporting', ...
# 1     [{'user_id': 73705, 'category': 'supporting', ...
# 3697  [{'user_id': 262752, 'category': 'improving', ...
# 3702  [{'user_id': 262752, 'category': None, 'disagr...
# 3707  [{'user_id': 262752, 'category': 'improving', ...
#
#                                             challenge  \
# 0     ../data/observations_final\CNC_Los_Angeles_2017
# 1     ../data/observations_final\CNC_Los_Angeles_2017
# 3697  ../data/observations_final\CNC_Los_Angeles_2017
# 3702  ../data/observations_final\CNC_Los_Angeles_2017
# 3707  ../data/observations_final\CNC_Los_Angeles_2017
#
#                          geometry  index_right
# 0     POINT (-118.20138 34.09752)         3033
# 1     POINT (-118.20141 34.09936)         3033
# 3697  POINT (-118.20125 34.09777)         3033
# 3702  POINT (-118.20125 34.09777)         3033
# 3707  POINT (-118.20125 34.09777)         3033
#
# [5 rows x 41 columns]

# %%
points_polys.shape
# Out:
# (22136, 41)

# %%
points_polys.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ## Set flag for greenspaces

# %%
ids_with_greenspace = points_polys.id.to_list()

# %%
new_la = la_df.set_index('id')
new_la.head()
# Out:
#                               observed_on_string           time_observed_at  \
# id
# 5591391  Fri Apr 14 2017 09:34:12 GMT-0700 (PDT)  2017-04-14T09:34:12-07:00
# 5591694  Sat Apr 15 2017 10:18:50 GMT-0700 (PDT)  2017-04-15T10:18:50-07:00
# 5684540  Fri Apr 14 2017 00:03:16 GMT-0700 (PDT)  2017-04-14T00:03:16-07:00
# 5684550  Fri Apr 14 2017 00:04:42 GMT-0700 (PDT)  2017-04-14T00:04:42-07:00
# 5684551  Fri Apr 14 2017 00:04:06 GMT-0700 (PDT)  2017-04-14T00:04:06-07:00
#
#            created_time_zone                 created_at  \
# id
# 5591391  America/Los_Angeles  2017-04-06T09:34:29-07:00
# 5591694  America/Los_Angeles  2017-04-06T10:19:03-07:00
# 5684540  America/Los_Angeles  2017-04-14T00:04:16-07:00
# 5684550  America/Los_Angeles  2017-04-14T00:05:31-07:00
# 5684551  America/Los_Angeles  2017-04-14T00:05:32-07:00
#
#                         updated_at description  user_id user_login  \
# id
# 5591391  2018-01-13T14:28:01-08:00         NaN   436798  laurachun
# 5591694  2018-01-13T14:28:03-08:00         NaN   436798  laurachun
# 5684540  2018-01-13T14:31:44-08:00         NaN     6743   lhiggins
# 5684550  2018-01-13T14:31:44-08:00         NaN     6743   lhiggins
# 5684551  2017-04-14T05:30:19-07:00         NaN    15419  mordenana
#
#         quality_grade                                       reviewed_by  ...  \
# id                                                                       ...
# 5591391      research                             [1850, 73705, 436798]  ...
# 5591694      research                       [1850, 6971, 73705, 436798]  ...
# 5684540      needs_id                       [1850, 6743, 52839, 275891]  ...
# 5684550      needs_id  [1850, 6743, 10285, 12809, 73705, 81261, 440756]  ...
# 5684551      needs_id                                     [1850, 15419]  ...
#
#          taxon_rank  taxon_parent_id  taxon_native  taxon_endemic  \
# id
# 5591391     species            52855          True          False
# 5591694     species            53145          True          False
# 5684540      family            52380         False          False
# 5684550       genus           933174         False          False
# 5684551       order            47119         False          False
#
#          taxon_threatened  taxon_search_rank taxon_observations  \
# id
# 5591391             False              11983              11983
# 5591694             False               6476               6476
# 5684540             False              55396              55396
# 5684550             False               8938               8938
# 5684551             False            1420015            1420015
#
#                                            identifications  \
# id
# 5591391  [{'user_id': 73705, 'category': 'supporting', ...
# 5591694  [{'user_id': 73705, 'category': 'supporting', ...
# 5684540  [{'user_id': 275891, 'category': 'supporting',...
# 5684550  [{'user_id': 81261, 'category': 'improving', '...
# 5684551  [{'user_id': 15419, 'category': None, 'disagre...
#
#                                                challenge  \
# id
# 5591391  ../data/observations_final\CNC_Los_Angeles_2017
# 5591694  ../data/observations_final\CNC_Los_Angeles_2017
# 5684540  ../data/observations_final\CNC_Los_Angeles_2017
# 5684550  ../data/observations_final\CNC_Los_Angeles_2017
# 5684551  ../data/observations_final\CNC_Los_Angeles_2017
#
#                             geometry
# id
# 5591391  POINT (-118.20138 34.09752)
# 5591694  POINT (-118.20141 34.09936)
# 5684540  POINT (-118.31088 34.07109)
# 5684550  POINT (-118.31077 34.07111)
# 5684551  POINT (-117.99642 34.14409)
#
# [5 rows x 39 columns]

# %%
new_la['greenspace_flag'] = '0'
new_la.loc[ids_with_greenspace,'greenspace_flag'] = '1'

# %%
new_la.greenspace_flag.value_counts()
# Out:
# 0    69557
# 1    22136
# Name: greenspace_flag, dtype: int64

# %%
#export as csv
new_la.to_csv('../data/outputs/la_data_with_greenspace_flag.csv')
