# %% [markdown]
# # Get the greenspaces from London and set the flags

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, Polygon
from glob2 import glob
import osmnx as ox

# %%
green=gpd.read_file('../data/outputs/greenspaces_ldn_final.shp')

# %%
green.shape
# Out:
# (32758, 2)

# %%
green.head()
# Out:
#    FID                                           geometry
# 0    0  POLYGON ((-0.16633 51.21638, -0.16650 51.21593...
# 1    1  POLYGON ((-0.34201 51.21249, -0.34125 51.21270...
# 2    2  POLYGON ((0.00256 51.23937, 0.00299 51.23896, ...
# 3    3  POLYGON ((-0.23174 51.24215, -0.23167 51.24220...
# 4    4  POLYGON ((-0.32467 51.24743, -0.32462 51.24744...

# %%
#get California as gdf to check anomalies later. Points outside England will be excluded
engl=ox.geocode_to_gdf('England')

# %%
engl
# Out:
#                                             geometry  bbox_north  bbox_south  \
# 0  POLYGON ((-6.70475 49.94700, -6.70473 49.94500...      55.917      49.674
#
#    bbox_east  bbox_west   place_id  osm_type  osm_id        lat       lon  \
# 0   2.091912  -6.704749  258567595  relation   58447  52.531021 -1.264906
#
#               display_name     class            type  importance
# 0  England, United Kingdom  boundary  administrative    0.948749

# %% [markdown]
# ## Load observations (API)

# %%
data_folder = '../data/observations_final'
df = pd.concat([pd.read_csv(f).assign(challenge=f.replace('.csv','')) for f in glob(data_folder+'/CNC_London_*.csv')])

# %%
df.shape
# Out:
# (13750, 39)

# %%
#check for incorrect points (lat)
df['latitude'].min(), df['latitude'].max()
# Out:
# (51.2037968565, 51.798367500299996)

# %%
#check for incorrect points (lon). Clearly something wrong!
df['longitude'].min(), df['longitude'].max()
# Out:
# (-0.5176091555, 0.2358256956)

# %% [markdown]
# ## Get only the points inside CA

# %%
df=df[df['latitude'].le(engl['bbox_north'].iloc[0]) \
                  & df['latitude'].ge(engl['bbox_south'].iloc[0]) \
                  & df['longitude'].le(engl['bbox_east'].iloc[0]) \
                  & df['longitude'].ge(engl['bbox_west'].iloc[0])]

# %%
df.shape
# Out:
# (13750, 39)

# %%
df.head()
# Out:
#          id                         observed_on_string  \
# 0  11479007                  2018-04-27 7:52:34 am BST
# 1  11480212                  2018-04-27 8:39:41 am BST
# 2  11480902  Fri Apr 27 2018 08:34:31 GMT+0100 (GMT+1)
# 3  11481097  Fri Apr 27 2018 09:54:35 GMT+0100 (GMT+1)
# 4  11482247                  2018-04-27 8:42:21 am BST
#
#             time_observed_at created_time_zone                 created_at  \
# 0  2018-04-27T07:52:34+00:00           Etc/UTC  2018-04-27T07:06:17+00:00
# 1  2018-04-27T08:39:41+01:00     Europe/London  2018-04-27T09:02:52+01:00
# 2  2018-04-27T08:34:31+02:00  Europe/Amsterdam  2018-04-27T10:42:01+02:00
# 3  2018-04-27T09:54:35+02:00  Europe/Amsterdam  2018-04-27T10:54:45+02:00
# 4  2018-04-27T08:42:21+01:00     Europe/London  2018-04-27T11:09:55+01:00
#
#                   updated_at description  user_id       user_login  \
# 0  2018-04-27T09:26:56+00:00         NaN   159021             muki
# 1  2019-01-29T21:16:34+00:00         NaN   664459  lucyrobinsonnhm
# 2  2018-04-27T13:01:49+02:00         NaN   908315           tess26
# 3  2018-04-27T22:23:41+02:00         NaN   796473      bryonycross
# 4  2018-04-27T16:37:31+01:00         NaN   664459  lucyrobinsonnhm
#
#   quality_grade  ... iconic_taxon_name  taxon_rank  taxon_parent_id  \
# 0      research  ...           Plantae     species           204212
# 1      research  ...              Aves     variety             3017
# 2        casual  ...           Plantae     species            56095
# 3      research  ...           Plantae     species           156638
# 4      research  ...           Plantae      hybrid            49664
#
#    taxon_native  taxon_endemic  taxon_threatened  taxon_search_rank  \
# 0          True          False             False              27624
# 1         False          False             False              43329
# 2         False          False             False               2813
# 3         False          False             False               4639
# 4         False          False             False               5866
#
#   taxon_observations                                    identifications  \
# 0              27624  [{'user_id': 353381, 'category': 'improving', ...
# 1              43329  [{'user_id': 29729, 'category': 'supporting', ...
# 2               2813  [{'user_id': 908315, 'category': 'leading', 'd...
# 3               4639  [{'user_id': 160, 'category': 'improving', 'di...
# 4               5866  [{'user_id': 160, 'category': 'supporting', 'd...
#
#                                     challenge
# 0  ../data/observations_final\CNC_London_2018
# 1  ../data/observations_final\CNC_London_2018
# 2  ../data/observations_final\CNC_London_2018
# 3  ../data/observations_final\CNC_London_2018
# 4  ../data/observations_final\CNC_London_2018
#
# [5 rows x 39 columns]

# %% [markdown]
# ## Create gdf using the observations

# %%
df['longitude'].isna().sum(), df['latitude'].isna().sum()
# Out:
# (0, 0)

# %%
#create the points inverting the coordinates
geometry_invert = [Point(xy) for xy in zip(df.longitude, df.latitude)]

# %%
#crete a geodataframe with the observations
observations_gdf = gpd.GeoDataFrame(df, crs='epsg:4326', geometry=geometry_invert)

# %%
observations_gdf.shape
# Out:
# (13750, 40)

# %%
observations_gdf.head()
# Out:
#          id                         observed_on_string  \
# 0  11479007                  2018-04-27 7:52:34 am BST
# 1  11480212                  2018-04-27 8:39:41 am BST
# 2  11480902  Fri Apr 27 2018 08:34:31 GMT+0100 (GMT+1)
# 3  11481097  Fri Apr 27 2018 09:54:35 GMT+0100 (GMT+1)
# 4  11482247                  2018-04-27 8:42:21 am BST
#
#             time_observed_at created_time_zone                 created_at  \
# 0  2018-04-27T07:52:34+00:00           Etc/UTC  2018-04-27T07:06:17+00:00
# 1  2018-04-27T08:39:41+01:00     Europe/London  2018-04-27T09:02:52+01:00
# 2  2018-04-27T08:34:31+02:00  Europe/Amsterdam  2018-04-27T10:42:01+02:00
# 3  2018-04-27T09:54:35+02:00  Europe/Amsterdam  2018-04-27T10:54:45+02:00
# 4  2018-04-27T08:42:21+01:00     Europe/London  2018-04-27T11:09:55+01:00
#
#                   updated_at description  user_id       user_login  \
# 0  2018-04-27T09:26:56+00:00         NaN   159021             muki
# 1  2019-01-29T21:16:34+00:00         NaN   664459  lucyrobinsonnhm
# 2  2018-04-27T13:01:49+02:00         NaN   908315           tess26
# 3  2018-04-27T22:23:41+02:00         NaN   796473      bryonycross
# 4  2018-04-27T16:37:31+01:00         NaN   664459  lucyrobinsonnhm
#
#   quality_grade  ... taxon_rank  taxon_parent_id  taxon_native  taxon_endemic  \
# 0      research  ...    species           204212          True          False
# 1      research  ...    variety             3017         False          False
# 2        casual  ...    species            56095         False          False
# 3      research  ...    species           156638         False          False
# 4      research  ...     hybrid            49664         False          False
#
#    taxon_threatened  taxon_search_rank  taxon_observations  \
# 0             False              27624               27624
# 1             False              43329               43329
# 2             False               2813                2813
# 3             False               4639                4639
# 4             False               5866                5866
#
#                                      identifications  \
# 0  [{'user_id': 353381, 'category': 'improving', ...
# 1  [{'user_id': 29729, 'category': 'supporting', ...
# 2  [{'user_id': 908315, 'category': 'leading', 'd...
# 3  [{'user_id': 160, 'category': 'improving', 'di...
# 4  [{'user_id': 160, 'category': 'supporting', 'd...
#
#                                     challenge                   geometry
# 0  ../data/observations_final\CNC_London_2018  POINT (-0.22849 51.55064)
# 1  ../data/observations_final\CNC_London_2018  POINT (-0.17361 51.49528)
# 2  ../data/observations_final\CNC_London_2018  POINT (-0.16910 51.47298)
# 3  ../data/observations_final\CNC_London_2018  POINT (-0.16152 51.50808)
# 4  ../data/observations_final\CNC_London_2018  POINT (-0.17389 51.49611)
#
# [5 rows x 40 columns]

# %% [markdown]
# ## Spatial join

# %%
# spatial join observations and observations.
points_polys = gpd.sjoin(observations_gdf, green, how='inner')

# %%
points_polys.head()
# Out:
#           id                         observed_on_string  \
# 3   11481097  Fri Apr 27 2018 09:54:35 GMT+0100 (GMT+1)
# 5   11482706  Fri Apr 27 2018 11:40:06 GMT+0100 (GMT+1)
# 6   11483083  Fri Apr 27 2018 12:01:15 GMT+0100 (GMT+1)
# 10  11484564  Fri Apr 27 2018 12:58:17 GMT+0100 (GMT+1)
# 11  11484587  Fri Apr 27 2018 12:58:55 GMT+0100 (GMT+1)
#
#              time_observed_at created_time_zone                 created_at  \
# 3   2018-04-27T09:54:35+02:00  Europe/Amsterdam  2018-04-27T10:54:45+02:00
# 5   2018-04-27T11:40:06+02:00  Europe/Amsterdam  2018-04-27T12:40:31+02:00
# 6   2018-04-27T12:01:15+02:00  Europe/Amsterdam  2018-04-27T13:01:48+02:00
# 10  2018-04-27T12:58:17+02:00  Europe/Amsterdam  2018-04-27T13:58:34+02:00
# 11  2018-04-27T12:58:55+02:00  Europe/Amsterdam  2018-04-27T13:59:13+02:00
#
#                    updated_at  \
# 3   2018-04-27T22:23:41+02:00
# 5   2018-04-27T19:18:08+02:00
# 6   2018-04-27T19:18:09+02:00
# 10  2018-04-27T19:18:10+02:00
# 11  2018-04-27T19:18:11+02:00
#
#                                           description  user_id   user_login  \
# 3                                                 NaN   796473  bryonycross
# 5                                                 NaN   796473  bryonycross
# 6                                                 NaN   796473  bryonycross
# 10  Large tree, medium sized leaves that are mostl...   796473  bryonycross
# 11  Large tree, medium sized leaves that are mostl...   796473  bryonycross
#
#    quality_grade  ... taxon_native  taxon_endemic  taxon_threatened  \
# 3       research  ...        False          False             False
# 5         casual  ...        False          False             False
# 6       needs_id  ...        False          False             False
# 10      research  ...        False          False             False
# 11      needs_id  ...        False          False             False
#
#     taxon_search_rank  taxon_observations  \
# 3                4639                4639
# 5                6135                6135
# 6               42225               42225
# 10              28819               28819
# 11               4080                4080
#
#                                       identifications  \
# 3   [{'user_id': 160, 'category': 'improving', 'di...
# 5   [{'user_id': 796473, 'category': 'leading', 'd...
# 6   [{'user_id': 796473, 'category': 'leading', 'd...
# 10  [{'user_id': 796473, 'category': 'improving', ...
# 11  [{'user_id': 796473, 'category': 'leading', 'd...
#
#                                      challenge                   geometry  \
# 3   ../data/observations_final\CNC_London_2018  POINT (-0.16152 51.50808)
# 5   ../data/observations_final\CNC_London_2018  POINT (-0.16758 51.51051)
# 6   ../data/observations_final\CNC_London_2018  POINT (-0.16793 51.51077)
# 10  ../data/observations_final\CNC_London_2018  POINT (-0.16176 51.50792)
# 11  ../data/observations_final\CNC_London_2018  POINT (-0.16168 51.50783)
#
#    index_right    FID
# 3        32756  32756
# 5        32756  32756
# 6        32756  32756
# 10       32756  32756
# 11       32756  32756
#
# [5 rows x 42 columns]

# %%
points_polys.shape
# Out:
# (8356, 42)

# %%
points_polys.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ## Set flag for greenspaces

# %%
ids_with_greenspace = points_polys.id.to_list()

# %%
new_df = df.set_index('id')
new_df.head()
# Out:
#                                  observed_on_string  \
# id
# 11479007                  2018-04-27 7:52:34 am BST
# 11480212                  2018-04-27 8:39:41 am BST
# 11480902  Fri Apr 27 2018 08:34:31 GMT+0100 (GMT+1)
# 11481097  Fri Apr 27 2018 09:54:35 GMT+0100 (GMT+1)
# 11482247                  2018-04-27 8:42:21 am BST
#
#                    time_observed_at created_time_zone  \
# id
# 11479007  2018-04-27T07:52:34+00:00           Etc/UTC
# 11480212  2018-04-27T08:39:41+01:00     Europe/London
# 11480902  2018-04-27T08:34:31+02:00  Europe/Amsterdam
# 11481097  2018-04-27T09:54:35+02:00  Europe/Amsterdam
# 11482247  2018-04-27T08:42:21+01:00     Europe/London
#
#                          created_at                 updated_at description  \
# id
# 11479007  2018-04-27T07:06:17+00:00  2018-04-27T09:26:56+00:00         NaN
# 11480212  2018-04-27T09:02:52+01:00  2019-01-29T21:16:34+00:00         NaN
# 11480902  2018-04-27T10:42:01+02:00  2018-04-27T13:01:49+02:00         NaN
# 11481097  2018-04-27T10:54:45+02:00  2018-04-27T22:23:41+02:00         NaN
# 11482247  2018-04-27T11:09:55+01:00  2018-04-27T16:37:31+01:00         NaN
#
#           user_id       user_login quality_grade  \
# id
# 11479007   159021             muki      research
# 11480212   664459  lucyrobinsonnhm      research
# 11480902   908315           tess26        casual
# 11481097   796473      bryonycross      research
# 11482247   664459  lucyrobinsonnhm      research
#
#                                               reviewed_by  ...  taxon_rank  \
# id                                                         ...
# 11479007            [160, 353381, 599476, 664459, 743476]  ...     species
# 11480212  [29729, 42615, 599476, 664459, 790453, 1082970]  ...     variety
# 11480902                                         [908315]  ...     species
# 11481097                    [160, 353381, 599476, 796473]  ...     species
# 11482247                    [160, 353381, 599476, 664459]  ...      hybrid
#
#           taxon_parent_id  taxon_native  taxon_endemic  taxon_threatened  \
# id
# 11479007           204212          True          False             False
# 11480212             3017         False          False             False
# 11480902            56095         False          False             False
# 11481097           156638         False          False             False
# 11482247            49664         False          False             False
#
#           taxon_search_rank taxon_observations  \
# id
# 11479007              27624              27624
# 11480212              43329              43329
# 11480902               2813               2813
# 11481097               4639               4639
# 11482247               5866               5866
#
#                                             identifications  \
# id
# 11479007  [{'user_id': 353381, 'category': 'improving', ...
# 11480212  [{'user_id': 29729, 'category': 'supporting', ...
# 11480902  [{'user_id': 908315, 'category': 'leading', 'd...
# 11481097  [{'user_id': 160, 'category': 'improving', 'di...
# 11482247  [{'user_id': 160, 'category': 'supporting', 'd...
#
#                                            challenge  \
# id
# 11479007  ../data/observations_final\CNC_London_2018
# 11480212  ../data/observations_final\CNC_London_2018
# 11480902  ../data/observations_final\CNC_London_2018
# 11481097  ../data/observations_final\CNC_London_2018
# 11482247  ../data/observations_final\CNC_London_2018
#
#                            geometry
# id
# 11479007  POINT (-0.22849 51.55064)
# 11480212  POINT (-0.17361 51.49528)
# 11480902  POINT (-0.16910 51.47298)
# 11481097  POINT (-0.16152 51.50808)
# 11482247  POINT (-0.17389 51.49611)
#
# [5 rows x 39 columns]

# %%
new_df['greenspace_flag'] = '0'
new_df.loc[ids_with_greenspace,'greenspace_flag'] = '1'

# %%
new_df.greenspace_flag.value_counts()
# Out:
# 1    8356
# 0    5394
# Name: greenspace_flag, dtype: int64

# %%
#export as csv
new_df.to_csv('../data/outputs/ldn_data_with_greenspace_flag_v2.csv')
