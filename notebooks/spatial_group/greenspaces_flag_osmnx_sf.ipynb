# %% [markdown]
# # Get the greenspaces from San Francisco and set the flags

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, Polygon
from glob2 import glob
import osmnx as ox

# %%
#get California as gdf to check anomalies later. Points outside California will be excluded
ca=ox.geocode_to_gdf('California')

# %%
ca
# Out:
#                                             geometry  bbox_north  bbox_south  \
# 0  MULTIPOLYGON (((-124.48200 40.44032, -124.4813...   42.009499   32.529524
#
#     bbox_east   bbox_west   place_id  osm_type  osm_id        lat         lon  \
# 0 -114.130782 -124.482003  259044285  relation  165475  36.701463 -118.755997
#
#                 display_name     class            type  importance
# 0  California, United States  boundary  administrative    0.922136

# %% [markdown]
# ## Load observations (API)

# %%
data_folder = '../data/observations_final'
sf_df = pd.concat([pd.read_csv(f).assign(challenge=f.replace('.csv','')) for f in glob(data_folder+'/CNC_San_Francisco_*.csv')])

# %%
sf_df.shape
# Out:
# (139040, 39)

# %%
#check for incorrect points (lat)
sf_df['latitude'].min(), sf_df['latitude'].max()
# Out:
# (36.998305700500005, 48.458352000000005)

# %%
#check for incorrect points (lon). Clearly something wrong!
sf_df['longitude'].min(), sf_df['longitude'].max()
# Out:
# (-123.59913058040001, -35.15625)

# %% [markdown]
# ## Get only the points inside CA

# %%
sf_df=sf_df[sf_df['latitude'].le(ca['bbox_north'].iloc[0]) \
                  & sf_df['latitude'].ge(ca['bbox_south'].iloc[0]) \
                  & sf_df['longitude'].le(ca['bbox_east'].iloc[0]) \
                  & sf_df['longitude'].ge(ca['bbox_west'].iloc[0])]

# %%
sf_df.shape
# Out:
# (139038, 39)

# %%
sf_df.head()
# Out:
#         id                       observed_on_string  \
# 0  5677489  Thu Apr 13 2017 12:40:50 GMT-0700 (PDT)
# 1  5682279  Thu Apr 13 2017 15:57:53 GMT-0700 (PDT)
# 2  5682371  Thu Apr 13 2017 16:08:07 GMT-0700 (PDT)
# 3  5684642                  2017/04/14 12:13 AM PDT
# 4  5684660  Fri Apr 14 2017 00:28:12 GMT-0700 (PDT)
#
#             time_observed_at    created_time_zone                 created_at  \
# 0  2017-04-13T12:40:50-07:00  America/Los_Angeles  2017-04-13T13:29:41-07:00
# 1  2017-04-13T15:57:53-07:00  America/Los_Angeles  2017-04-13T18:37:08-07:00
# 2  2017-04-13T16:08:07-07:00  America/Los_Angeles  2017-04-13T18:44:41-07:00
# 3  2017-04-14T00:13:00-07:00  America/Los_Angeles  2017-04-14T00:20:21-07:00
# 4  2017-04-14T00:28:12-07:00  America/Los_Angeles  2017-04-14T00:29:36-07:00
#
#                   updated_at description  user_id   user_login quality_grade  \
# 0  2018-11-26T12:33:26-08:00         NaN     8778  gyrrlfalcon      needs_id
# 1  2018-11-26T06:03:56-08:00         NaN     4797     paranger      research
# 2  2018-11-26T06:03:57-08:00         NaN     4797     paranger      research
# 3  2017-04-21T14:58:31-07:00         NaN        1        kueda      needs_id
# 4  2020-02-15T14:31:49-08:00         NaN     3494   damontighe      needs_id
#
#    ... iconic_taxon_name  taxon_rank  taxon_parent_id  taxon_native  \
# 0  ...           Insecta      family            49025         False
# 1  ...           Plantae     species            48245          True
# 2  ...           Plantae     species            48245          True
# 3  ...           Insecta      family            55518         False
# 4  ...           Insecta    subgenus            67740         False
#
#    taxon_endemic  taxon_threatened  taxon_search_rank taxon_observations  \
# 0          False             False             127627             127627
# 1          False             False               8756               8756
# 2          False             False               8756               8756
# 3          False             False               6696               6696
# 4          False             False               1246               1246
#
#                                      identifications  \
# 0  [{'user_id': 8778, 'category': 'maverick', 'di...
# 1  [{'user_id': 179103, 'category': 'supporting',...
# 2  [{'user_id': 179103, 'category': 'supporting',...
# 3  [{'user_id': 1, 'category': None, 'disagreemen...
# 4  [{'user_id': 3494, 'category': 'leading', 'dis...
#
#                                            challenge
# 0  ../data/observations_final\CNC_San_Francisco_2017
# 1  ../data/observations_final\CNC_San_Francisco_2017
# 2  ../data/observations_final\CNC_San_Francisco_2017
# 3  ../data/observations_final\CNC_San_Francisco_2017
# 4  ../data/observations_final\CNC_San_Francisco_2017
#
# [5 rows x 39 columns]

# %% [markdown]
# ## Get the greenspaces using OSMnx and the points we defined before

# %%
green=ox.geometries.geometries_from_bbox(sf_df['latitude'].max(),
                                         sf_df['latitude'].min(),
                                         sf_df['longitude'].max(),
                                         sf_df['longitude'].min(),
                                         {'leisure':'park', 'landuse':'forest'})

# %%
green.shape
# Out:
# (5513, 251)

# %%
green.head(5)
# Out:
#       unique_id     osmid element_type natural  \
# 0  way/40180966  40180966          way     NaN
# 1  way/40181141  40181141          way     NaN
# 2  way/64295487  64295487          way     NaN
# 3  way/64295496  64295496          way     NaN
# 4  way/64295506  64295506          way     NaN
#
#                                             geometry  \
# 0  POLYGON ((-123.27734 38.53263, -123.27735 38.5...
# 1  POLYGON ((-123.26371 38.52568, -123.26437 38.5...
# 2  POLYGON ((-123.32040 38.56862, -123.32039 38.5...
# 3  POLYGON ((-123.32971 38.57325, -123.32853 38.5...
# 4  POLYGON ((-123.33315 38.57426, -123.33296 38.5...
#
#                                                nodes  \
# 0  [484049095, 484049109, 484049122, 484049138, 4...
# 1  [484078428, 484078426, 484078423, 484078461, 4...
# 2  [791632646, 791644817, 791637347, 791649272, 7...
# 3  [791652840, 791636321, 791657111, 791640229, 7...
# 4  [791660111, 791652683, 791636224, 791653565, 7...
#
#                                      attribution  \
# 0                         CASIL CSP_Opbdys072008
# 1                         CASIL CSP_Opbdys072008
# 2  USDA-Forest Service, Pacific Southwest Region
# 3  USDA-Forest Service, Pacific Southwest Region
# 4  USDA-Forest Service, Pacific Southwest Region
#
#                              csp:globalid csp:unitcode leisure  ... name:vi  \
# 0  {C334A2B5-47D3-4FCC-A296-BEDD15BFEC9B}          207    park  ...     NaN
# 1  {C334A2B5-47D3-4FCC-A296-BEDD15BFEC9B}          207    park  ...     NaN
# 2                                     NaN          NaN     NaN  ...     NaN
# 3                                     NaN          NaN     NaN  ...     NaN
# 4                                     NaN          NaN     NaN  ...     NaN
#
#   addr:full source:address source:name park abandoned:landuse addr:housename  \
# 0       NaN            NaN         NaN  NaN               NaN            NaN
# 1       NaN            NaN         NaN  NaN               NaN            NaN
# 2       NaN            NaN         NaN  NaN               NaN            NaN
# 3       NaN            NaN         NaN  NaN               NaN            NaN
# 4       NaN            NaN         NaN  NaN               NaN            NaN
#
#   source:geometry path  key
# 0             NaN  NaN  NaN
# 1             NaN  NaN  NaN
# 2             NaN  NaN  NaN
# 3             NaN  NaN  NaN
# 4             NaN  NaN  NaN
#
# [5 rows x 251 columns]

# %%
#keep only polygons

#exclude Point
green=green[green['geometry'].geom_type.ne('Point')]
#exclude LineString
green=green[green['geometry'].geom_type.ne('LineString')]

# %%
green.shape
# Out:
# (4879, 251)

# %% [markdown]
# ## Exclude the overlapping geometries

# %%
geom = green.geometry.unary_union

# %%
green_unique = gpd.GeoDataFrame(geometry=[geom],crs='epsg:4326')

# %%
green_unique.head()
# Out:
#                                             geometry
# 0  MULTIPOLYGON (((-121.85857 37.01905, -121.8586...

# %%
green_unique.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
green_unique = green_unique.explode().reset_index(drop=True)

# %%
green_unique.head()
# Out:
#                                             geometry
# 0  POLYGON ((-121.85857 37.01905, -121.85863 37.0...
# 1  POLYGON ((-121.77653 37.02668, -121.77658 37.0...
# 2  POLYGON ((-122.24431 37.09292, -122.24920 37.0...
# 3  POLYGON ((-122.19112 37.12759, -122.19956 37.1...
# 4  POLYGON ((-121.55997 37.00585, -121.55924 37.0...

# %%
green_unique.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
green_unique.shape
# Out:
# (4631, 1)

# %% [markdown]
# ## Create gdf using the observations

# %%
sf_df['longitude'].isna().sum(), sf_df['latitude'].isna().sum()
# Out:
# (0, 0)

# %%
#create the points inverting the coordinates
geometry_invert = [Point(xy) for xy in zip(sf_df.longitude, sf_df.latitude)]

# %%
#crete a geodataframe with the observations
observations_gdf = gpd.GeoDataFrame(sf_df, crs='epsg:4326', geometry=geometry_invert)

# %%
observations_gdf.shape
# Out:
# (139038, 40)

# %%
observations_gdf.head()
# Out:
#         id                       observed_on_string  \
# 0  5677489  Thu Apr 13 2017 12:40:50 GMT-0700 (PDT)
# 1  5682279  Thu Apr 13 2017 15:57:53 GMT-0700 (PDT)
# 2  5682371  Thu Apr 13 2017 16:08:07 GMT-0700 (PDT)
# 3  5684642                  2017/04/14 12:13 AM PDT
# 4  5684660  Fri Apr 14 2017 00:28:12 GMT-0700 (PDT)
#
#             time_observed_at    created_time_zone                 created_at  \
# 0  2017-04-13T12:40:50-07:00  America/Los_Angeles  2017-04-13T13:29:41-07:00
# 1  2017-04-13T15:57:53-07:00  America/Los_Angeles  2017-04-13T18:37:08-07:00
# 2  2017-04-13T16:08:07-07:00  America/Los_Angeles  2017-04-13T18:44:41-07:00
# 3  2017-04-14T00:13:00-07:00  America/Los_Angeles  2017-04-14T00:20:21-07:00
# 4  2017-04-14T00:28:12-07:00  America/Los_Angeles  2017-04-14T00:29:36-07:00
#
#                   updated_at description  user_id   user_login quality_grade  \
# 0  2018-11-26T12:33:26-08:00         NaN     8778  gyrrlfalcon      needs_id
# 1  2018-11-26T06:03:56-08:00         NaN     4797     paranger      research
# 2  2018-11-26T06:03:57-08:00         NaN     4797     paranger      research
# 3  2017-04-21T14:58:31-07:00         NaN        1        kueda      needs_id
# 4  2020-02-15T14:31:49-08:00         NaN     3494   damontighe      needs_id
#
#    ... taxon_rank  taxon_parent_id  taxon_native  taxon_endemic  \
# 0  ...     family            49025         False          False
# 1  ...    species            48245          True          False
# 2  ...    species            48245          True          False
# 3  ...     family            55518         False          False
# 4  ...   subgenus            67740         False          False
#
#    taxon_threatened  taxon_search_rank  taxon_observations  \
# 0             False             127627              127627
# 1             False               8756                8756
# 2             False               8756                8756
# 3             False               6696                6696
# 4             False               1246                1246
#
#                                      identifications  \
# 0  [{'user_id': 8778, 'category': 'maverick', 'di...
# 1  [{'user_id': 179103, 'category': 'supporting',...
# 2  [{'user_id': 179103, 'category': 'supporting',...
# 3  [{'user_id': 1, 'category': None, 'disagreemen...
# 4  [{'user_id': 3494, 'category': 'leading', 'dis...
#
#                                            challenge  \
# 0  ../data/observations_final\CNC_San_Francisco_2017
# 1  ../data/observations_final\CNC_San_Francisco_2017
# 2  ../data/observations_final\CNC_San_Francisco_2017
# 3  ../data/observations_final\CNC_San_Francisco_2017
# 4  ../data/observations_final\CNC_San_Francisco_2017
#
#                       geometry
# 0  POINT (-122.07613 37.42187)
# 1  POINT (-122.18080 37.35370)
# 2  POINT (-122.18041 37.35305)
# 3  POINT (-122.37434 37.89112)
# 4  POINT (-122.26543 37.80403)
#
# [5 rows x 40 columns]

# %% [markdown]
# ## Spatial join

# %%
# spatial join observations and observations.
points_polys = gpd.sjoin(observations_gdf, green_unique, how='inner')

# %%
points_polys.head()
# Out:
#             id                       observed_on_string  \
# 14     5686895  Fri Apr 14 2017 06:58:12 GMT-0700 (PDT)
# 2993  43217084  Fri Apr 24 2020 12:07:24 GMT-0700 (PDT)
# 2995  43217209  Fri Apr 24 2020 12:05:31 GMT-0700 (PDT)
# 9890  43484693  Sat Apr 25 2020 12:21:51 GMT-0700 (PDT)
# 9894  43484777  Sat Apr 25 2020 12:20:56 GMT-0700 (PDT)
#
#                time_observed_at    created_time_zone  \
# 14    2017-04-14T06:58:12-07:00  America/Los_Angeles
# 2993  2020-04-24T12:07:24-07:00  America/Los_Angeles
# 2995  2020-04-24T12:05:31-07:00  America/Los_Angeles
# 9890  2020-04-25T12:21:51-07:00  America/Los_Angeles
# 9894  2020-04-25T12:20:56-07:00  America/Los_Angeles
#
#                      created_at                 updated_at  \
# 14    2017-04-14T07:04:33-07:00  2017-04-14T19:07:05-07:00
# 2993  2020-04-24T17:18:05-07:00  2020-04-24T19:46:41-07:00
# 2995  2020-04-24T17:18:43-07:00  2020-04-24T17:26:40-07:00
# 9890  2020-04-25T16:24:08-07:00  2020-04-25T16:24:28-07:00
# 9894  2020-04-25T16:24:32-07:00  2020-05-03T00:45:14-07:00
#
#                                             description  user_id  user_login  \
# 14                                                  NaN      819  rebeccafay
# 2993  Lots of Douglas iris, but the first Fernald's ...      819  rebeccafay
# 2995  Lots of Douglas iris, but the first Fernald's ...      819  rebeccafay
# 9890                   Kite Hill Ecological Restoration      819  rebeccafay
# 9894                   Kite Hill Ecological Restoration      819  rebeccafay
#
#      quality_grade  ... taxon_parent_id  taxon_native  taxon_endemic  \
# 14        needs_id  ...          311249         False          False
# 2993      research  ...            9091          True          False
# 2995      research  ...           13847         False          False
# 9890      needs_id  ...           47689         False          False
# 9894      needs_id  ...          738398         False          False
#
#       taxon_threatened  taxon_search_rank  taxon_observations  \
# 14               False             229816              229816
# 2993             False              62760               62760
# 2995             False             107159              107159
# 9890             False             128961              128961
# 9894             False              19325               19325
#
#                                         identifications  \
# 14    [{'user_id': 819, 'category': 'improving', 'di...
# 2993  [{'user_id': 819, 'category': 'improving', 'di...
# 2995  [{'user_id': 819, 'category': 'improving', 'di...
# 9890  [{'user_id': 819, 'category': 'leading', 'disa...
# 9894  [{'user_id': 819, 'category': 'improving', 'di...
#
#                                               challenge  \
# 14    ../data/observations_final\CNC_San_Francisco_2017
# 2993  ../data/observations_final\CNC_San_Francisco_2020
# 2995  ../data/observations_final\CNC_San_Francisco_2020
# 9890  ../data/observations_final\CNC_San_Francisco_2020
# 9894  ../data/observations_final\CNC_San_Francisco_2020
#
#                          geometry  index_right
# 14    POINT (-122.43269 37.80152)         1996
# 2993  POINT (-122.43458 37.80227)         1996
# 2995  POINT (-122.43429 37.80120)         1996
# 9890  POINT (-122.43182 37.80275)         1996
# 9894  POINT (-122.43183 37.80264)         1996
#
# [5 rows x 41 columns]

# %%
points_polys.shape
# Out:
# (41060, 41)

# %%
points_polys.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ## Set flag for greenspaces

# %%
ids_with_greenspace = points_polys.id.to_list()

# %%
new_sf = sf_df.set_index('id')
new_sf.head()
# Out:
#                               observed_on_string           time_observed_at  \
# id
# 5677489  Thu Apr 13 2017 12:40:50 GMT-0700 (PDT)  2017-04-13T12:40:50-07:00
# 5682279  Thu Apr 13 2017 15:57:53 GMT-0700 (PDT)  2017-04-13T15:57:53-07:00
# 5682371  Thu Apr 13 2017 16:08:07 GMT-0700 (PDT)  2017-04-13T16:08:07-07:00
# 5684642                  2017/04/14 12:13 AM PDT  2017-04-14T00:13:00-07:00
# 5684660  Fri Apr 14 2017 00:28:12 GMT-0700 (PDT)  2017-04-14T00:28:12-07:00
#
#            created_time_zone                 created_at  \
# id
# 5677489  America/Los_Angeles  2017-04-13T13:29:41-07:00
# 5682279  America/Los_Angeles  2017-04-13T18:37:08-07:00
# 5682371  America/Los_Angeles  2017-04-13T18:44:41-07:00
# 5684642  America/Los_Angeles  2017-04-14T00:20:21-07:00
# 5684660  America/Los_Angeles  2017-04-14T00:29:36-07:00
#
#                         updated_at description  user_id   user_login  \
# id
# 5677489  2018-11-26T12:33:26-08:00         NaN     8778  gyrrlfalcon
# 5682279  2018-11-26T06:03:56-08:00         NaN     4797     paranger
# 5682371  2018-11-26T06:03:57-08:00         NaN     4797     paranger
# 5684642  2017-04-21T14:58:31-07:00         NaN        1        kueda
# 5684660  2020-02-15T14:31:49-08:00         NaN     3494   damontighe
#
#         quality_grade                             reviewed_by  ...  \
# id                                                             ...
# 5677489      needs_id                  [8778, 275891, 425620]  ...
# 5682279      research                  [4797, 179103, 425620]  ...
# 5682371      research                  [4797, 179103, 425620]  ...
# 5684642      needs_id                             [1, 425620]  ...
# 5684660      needs_id  [3494, 179103, 212655, 425620, 477431]  ...
#
#          taxon_rank  taxon_parent_id  taxon_native  taxon_endemic  \
# id
# 5677489      family            49025         False          False
# 5682279     species            48245          True          False
# 5682371     species            48245          True          False
# 5684642      family            55518         False          False
# 5684660    subgenus            67740         False          False
#
#          taxon_threatened  taxon_search_rank taxon_observations  \
# id
# 5677489             False             127627             127627
# 5682279             False               8756               8756
# 5682371             False               8756               8756
# 5684642             False               6696               6696
# 5684660             False               1246               1246
#
#                                            identifications  \
# id
# 5677489  [{'user_id': 8778, 'category': 'maverick', 'di...
# 5682279  [{'user_id': 179103, 'category': 'supporting',...
# 5682371  [{'user_id': 179103, 'category': 'supporting',...
# 5684642  [{'user_id': 1, 'category': None, 'disagreemen...
# 5684660  [{'user_id': 3494, 'category': 'leading', 'dis...
#
#                                                  challenge  \
# id
# 5677489  ../data/observations_final\CNC_San_Francisco_2017
# 5682279  ../data/observations_final\CNC_San_Francisco_2017
# 5682371  ../data/observations_final\CNC_San_Francisco_2017
# 5684642  ../data/observations_final\CNC_San_Francisco_2017
# 5684660  ../data/observations_final\CNC_San_Francisco_2017
#
#                             geometry
# id
# 5677489  POINT (-122.07613 37.42187)
# 5682279  POINT (-122.18080 37.35370)
# 5682371  POINT (-122.18041 37.35305)
# 5684642  POINT (-122.37434 37.89112)
# 5684660  POINT (-122.26543 37.80403)
#
# [5 rows x 39 columns]

# %%
new_sf['greenspace_flag'] = '0'
new_sf.loc[ids_with_greenspace,'greenspace_flag'] = '1'

# %%
new_sf.greenspace_flag.value_counts()
# Out:
# 0    97978
# 1    41060
# Name: greenspace_flag, dtype: int64

# %%
#export as csv
new_sf.to_csv('../data/outputs/sf_data_with_greenspace_flag.csv')
