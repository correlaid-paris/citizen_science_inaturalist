# %%
# !pip install pyinaturalist
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.0/131.0 KB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.7/238.7 KB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 KB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 KB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 30.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 79.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.6.1
#     Uninstalling Pygments-2.6.1:
#       Successfully uninstalled Pygments-2.6.1
# ...

# %%
# !pip install retentioneering --pre
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.5/856.5 KB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 85.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.7/529.7 KB 38.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 82.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 81.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 86.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 MB 15.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.8/149.8 KB 15.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 75.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 KB 9.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install pyinaturalist_convert
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 KB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.6/48.6 KB 3.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# Replace YOUR_API_TOKEN with the "Observation API Token" you obtained from the iNaturalist website
#
# API token
# https://www.inaturalist.org/users/api_token
#
# "eyJhbGciOiJIUzUxMiJ9.eyJ1c2VyX2lkIjozNzUzMDExLCJleHAiOjE2NzkyNDE2MjJ9.UFUn2VPznCSeNMYnCA_x45Bq32hcRMt2ddLCxsTE4vd5Ot5eqN8Yz37uZolGAcgr9v0cHFyMjtNDQl2V4dr4zw"

# %%
import requests

# Set up API endpoint URL and headers
endpoint_url = 'https://api.inaturalist.org/v1/observations'
headers = {
    'Authorization': 'eyJhbGciOiJIUzUxMiJ9.eyJ1c2VyX2lkIjozNzUzMDExLCJleHAiOjE2NzkyNDE2MjJ9.UFUn2VPznCSeNMYnCA_x45Bq32hcRMt2ddLCxsTE4vd5Ot5eqN8Yz37uZolGAcgr9v0cHFyMjtNDQl2V4dr4zw',
    'Content-Type': 'application/json',
}

# Set up API request parameters
params = {
    'taxon_id': 1,
    'place_id': 1,
    'per_page': 10,
    'page': 1,
}

# Send API request and check response status code
response = requests.get(endpoint_url, headers=headers, params=params)
if response.status_code == 200:
    print('API request successful')
else:
    print('API request failed')

# Access response data in JSON format
data = response.json()

# Process response data as needed
print(data)
# Out:
# API request successful
# ...

# %%
import pandas as pd
from pyinaturalist import *
import inspect
from pyinaturalist_convert import *
import os

# getData,
# this function will use the pinaturalist package to 
# scrap the inaturalist website and get data,
# it will concatenate each page result to one dataset
# @param,
# @keyWord, the keyword / phrase to search
def getData(keyWord):
    dfList = []
    try:
        for page in range(1, 100):
            # tmp = get_observations(q="Harmonia Axyridis", d1 = "01/01/2018", d2 = "30/11/2022", lat=53.94220, lng=-3.96803, radius=511, per_page=400, page = page)
            tmp = get_observations(q=keyWord, d1 = "01/01/2018", d2 = "30/11/2022", lat=53.94220, lng=-3.96803, radius=511, per_page=400, page = page)
            dfList.append(to_dataframe(tmp))
    except Exception as e: 
        df = pd.concat(dfList)
        df = df[["quality_grade", "observed_on_details.date", "species_guess", "public_positional_accuracy", "taxon.name", "geojson.coordinates", "owners_identification_from_vision", "identification_count", "num_identification_disagreements", "location", "place_guess"]]
        df.to_csv("inat_data.csv", sep=",", index="False")
        
    print("data collection complete")


    
    
# filter Data,
# this function filter the dataset obtain in  the getData function
# to keep only columns of interest,
# it also convert the location column to latitude and longitude
# finally, it standardise the column name of our two dataset
def filterData():
    inat_df = pd.read_csv("inat_data.csv")
    inat_df = inat_df [["quality_grade", "observed_on_details.date", "species_guess", "public_positional_accuracy", "taxon.name", "geojson.coordinates", "owners_identification_from_vision", "identifications_count", "num_identification_disagreements", "location", "place_guess"]]
    latitude = []
    # print(inat_df.location.tolist())
    for val in inat_df.location.tolist():
        lat = float(val.split(",")[0].replace("[", "").replace("]","").replace(",", ""))
        latitude.append(lat)
    
    longitude= []
    for val in inat_df.location.tolist():
        lon= float(val.split(",")[1].replace("[", "").replace("]","").replace(",", ""))
        longitude.append(lon)
  
    inat_df= inat_df.assign(latitude = latitude)
    inat_df= inat_df.assign(longitude = longitude)

    article_df = pd.read_csv("article_data.csv")
    article_df.columns= article_df.columns.str.lower()
    article_df.to_csv("article_data.csv", sep=",", index=False)
    inat_df.to_csv("inat_data_filtered.csv", sep=",", index=False)


# getGrid,
# this function is a try of chunking a big density dataset to a usable for us
def getGrid():
    latList, longList, densityList = [], [], []
    for i,chunk in enumerate(pd.read_csv("population_gbr_2019-07-01.csv", chunksize=10000)):
        latList.append(round(chunk.tail(1).Lat.values[0], 3))
        longList.append(round(chunk.tail(1).Lon.values[0], 3))
        densityList.append(chunk.Population.sum())
    
    data = {"latitude": latList, "longitude":longList, "density":densityList}
    df = pd.DataFrame.from_dict(data)
    df.to_csv("density_try.csv", sep=",", index=False)
    
    # main,
    # main function to run our data collection and cleaning
def main():
    if not os.path.isfile("inat_data.csv"): getData()
    filterData()
    # getGrid()
    
#if __name__ == '__main__':
#    main()

# %% [markdown]
# Before running the code you need:
#
# Check the API documentation: Make sure you are using the correct endpoint and parameters to access the API. The documentation should provide you with the correct syntax to use.
#
# Authenticate yourself: If the server requires authentication, you will need to provide valid credentials, such as an API key or username and password, in order to access the resource. You can usually obtain these credentials by registering for an account with the API provider.

# %%
getData("Harmonia Axyridis")
